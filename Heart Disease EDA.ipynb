# %% [markdown]
# # **Heart Disese EDA**

# %% [markdown]
# ## Age(DistPlot)

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.shape
# Out:
# (918, 12)

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df['Age']
# Out:
# 0      40
# 1      49
# 2      37
# 3      48
# 4      54
#        ..
# 913    45
# 914    68
# 915    57
# 916    57
# 917    38
# Name: Age, Length: 918, dtype: int64

# %%
sns.displot(df['Age'] )

# %%
sns.displot(df['Age'] , kde = True)

# %%
sns.distplot(df['Age'],kde = True , hist = True , color = 'red')
# Out:
# C:\Users\Prikshit\AppData\Local\Temp\ipykernel_14260\2126391834.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],kde = True , hist = True , color = 'red')
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Age'],kde = True , hist = True , rug = True)
# Out:
# C:\Users\Prikshit\AppData\Local\Temp\ipykernel_14260\547256163.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'],kde = True , hist = True , rug = True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Age'] , bins = 10)
# Out:
# C:\Users\Prikshit\AppData\Local\Temp\ipykernel_14260\2370049603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'] , bins = 10)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Age'] , bins = 3)
# Out:
# C:\Users\Prikshit\AppData\Local\Temp\ipykernel_14260\3594756021.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'] , bins = 3)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['Age'] , bins = 100)
# Out:
# C:\Users\Prikshit\AppData\Local\Temp\ipykernel_14260\3442453365.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'] , bins = 100)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.displot(df['RestingBP'],kde = True , color = 'blue' )

# %%
sns.distplot(df['RestingBP'],kde = True , color = 'blue' )
# Out:
# C:\Users\Prikshit\AppData\Local\Temp\ipykernel_14260\4033427360.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['RestingBP'],kde = True , color = 'blue' )
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
sns.distplot(df['Cholesterol'],kde = True , color = 'blue' )
# Out:
# C:\Users\Prikshit\AppData\Local\Temp\ipykernel_14260\276672594.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Cholesterol'],kde = True , color = 'blue' )
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
sns.distplot(df['FastingBS'],kde = True , color = 'blue' )
# Out:
# C:\Users\Prikshit\AppData\Local\Temp\ipykernel_14260\3474439100.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['FastingBS'],kde = True , color = 'blue' )
# <Axes: xlabel='FastingBS', ylabel='Density'>

# %%
sns.distplot(df['MaxHR'],kde = True , color = 'blue' )
# Out:
# C:\Users\Prikshit\AppData\Local\Temp\ipykernel_14260\3723871688.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['MaxHR'],kde = True , color = 'blue' )
# <Axes: xlabel='MaxHR', ylabel='Density'>

# %%
sns.distplot(df['Oldpeak'],kde = True , color = 'blue' )
# Out:
# C:\Users\Prikshit\AppData\Local\Temp\ipykernel_14260\2314795973.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Oldpeak'],kde = True , color = 'blue' )
# <Axes: xlabel='Oldpeak', ylabel='Density'>

# %% [markdown]
# ## Ctegorical Columns (Pie Chart)

# %%
df.groupby('Sex').size()
# Out:
# Sex
# F    193
# M    725
# dtype: int64

# %%
df.groupby('Sex').size().plot(kind = 'pie' , autopct = '%.2f')
# Out:
# <Axes: >

# %%
df.groupby('ChestPainType').size().plot(kind = 'pie' , autopct = '%.2f')
# Out:
# <Axes: >

# %%
df.groupby('RestingECG').size().plot(kind = 'pie' , autopct = '%.2f')
# Out:
# <Axes: >

# %%
df.groupby('ST_Slope').size().plot(kind = 'pie' , autopct = '%.2f')
# Out:
# <Axes: >

# %%
df.groupby('HeartDisease').size().plot(kind = 'pie' , autopct = '%.2f')
# Out:
# <Axes: >

# %% [markdown]
# ## Violin Plot

# %%
sns.violinplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.violinplot( x = df['Sex'] , y =df['HeartDisease'] )
# Out:
# <Axes: xlabel='Sex', ylabel='HeartDisease'>

# %%
sns.violinplot(y = df['Age'] , x =df['HeartDisease'] )
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.violinplot(y = df['Cholesterol'] , x =df['HeartDisease'] )
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
sns.violinplot(y = df['RestingBP'] , x =df['HeartDisease'] )
# Out:
# <Axes: xlabel='HeartDisease', ylabel='RestingBP'>

# %%
sns.violinplot(y = df['MaxHR'] , x =df['HeartDisease'] )
# Out:
# <Axes: xlabel='HeartDisease', ylabel='MaxHR'>

# %% [markdown]
# ## Correlation

# %%
df.corr(numeric_only = True)
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.heatmap(df.corr(numeric_only = True) )
# Out:
# <Axes: >

# %% [markdown]
# ## JointPlot

# %%
sns.jointplot(x = 'Age' , y = 'MaxHR' , data =df)

# %%
sns.jointplot(x = 'Age' , y = 'MaxHR' , data =df , kind = 'hex')

# %%
sns.jointplot(x = 'RestingBP' , y = 'MaxHR' , data =df )

# %%
sns.jointplot(x = 'RestingBP' , y = 'MaxHR' , data =df , kind = 'hex')

# %%
sns.jointplot(x = 'Cholesterol' , y = 'Age' , data =df , kind = 'hex')

# %%
sns.jointplot(x = 'Age' , y = 'Age' , data =df , kind = 'hex')

# %%
sns.jointplot(x = 'Age' , y = 'MaxHR' , data =df , kind = 'reg')

# %%
sns.jointplot(x = 'Cholesterol' , y = 'FastingBS' , data =df , kind = 'hex')

# %%
sns.jointplot(x = 'Cholesterol' , y = 'FastingBS' , data =df , kind = 'reg')

# %%
sns.jointplot(x = 'Cholesterol' , y = 'HeartDisease' , data =df , kind = 'reg')

# %% [markdown]
# ## PairPlot

# %%
sns.pairplot(data = df )
